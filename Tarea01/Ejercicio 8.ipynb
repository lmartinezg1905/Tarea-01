# %%
#Ejercicio 8

print("Introduce un numero y se representara un triangulo rectangulo proporcional al numero dado")

x = int(input("Introduce un numero: "))
cont = 0 
while (cont< x):
  cont = cont + 1 
  print(cont * "*")
# Out:
# Introduce un numero y se representara un triangulo rectangulo proporcional al numero dado
# Introduce un numero: 4
# *
# **
# ***
# ****
