# %%
#Ejercicio 5 

print("Este programa te calcula el peso de n numero de payasos y juegos de mesa")

def peso(payaso, juego):
 payaso = 150
 pk = p*payaso
 print("El peso de", p, "es: ", pk, "kg")
 juego = 170
 jk = j*juego
 print("El peso de", j, "es: ", jk, "kg")
 z = pk + jk
 print("El peso total es de: ", z)
 if z>10000:
   print("Error")
   y = z-10000
   print("Se pasa por: ", y)
 else:
   print("Su compra ha sido realizada con exito")
p = int(input("Numero de payasos que desea comprar: "))
j = int(input("Numero de juegos de mesa que desea comprar: "))

peso(p, j)
# Out:
# Este programa te calcula el peso de n numero de payasos y juegos de mesa
# Numero de payasos que desea comprar: 100
# Numero de juegos de mesa que desea comprar: 200
# El peso de 100 es:  15000 kg
# El peso de 200 es:  34000 kg
# El peso total es de:  49000
# Error
# Se pasa por:  39000
