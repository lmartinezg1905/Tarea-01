# %%
#Ejercicio 6

print("Este progra te dice el impuesto que se debe pagar de acuerdo al ingreso mensual")

def impuesto(sueldo): 
  if x < 10000:  
   print("Usted debe pagar el %5 de su sueldo como impuesto")
   z = x * 0.05
   y = x - z
   print("Su sueldo final seria: ", y)
   return[z, True]
  elif (x >= 10000 and x <= 15000): 
   print("Usted debe pagar el %10 de su sueldo como impuesto")
   z = x * 0.1
   y = x - z 
   print("Su sueldo final seria: ", y)
   return[z, True]
  elif (x >= 15000 and x <= 20000):
   print("Usted debe pagar el %15 de su sueldo como impuesto")
   z = x * 0.15
   y = x - z
   print("Su sueldo final seria: ", y)
   return[z, True]
  else: 
    print("Usted debe pagar el %20 de su sueldo como impuesto")
    z = x * 0.2
    y = x - z
    print("Su sueldo final seria: ", y)
    return[z, True]
x = float(input("Introduzca su sueldo: "))

impuesto(x)
# Out:
# Este progra te dice el impuesto que se debe pagar de acuerdo al ingreso mensual
# Introduzca su sueldo: 11000
# Usted debe pagar el %10 de su sueldo como impuesto
# Su sueldo final seria:  9900.0
# [1100.0, True]
