# %%
#Ejercicio 9

def factorial():
  f=1
  x=int(input("Ingrese un número entero: "))
  for i in range (1,x+1):
    f=f*i
  print("El factorial de ese número es:",f)

factorial()
# Out:
# Ingrese un número entero: 5
# El factorial de ese número es: 120
