# %%
#Ejercicio 1 

print("Este programa te dice si el numero que ingresas es par o impar")
a = int(input('Introduce un numero: '))
if a % 2 == 0:
   print(a, "es un numero par")
else:
  print(a, "es un numero impar")
# Out:
# Este programa te dice si el numero que ingresas es par o impar
# Introduce un numero: 5
# 5 es un numero impar
