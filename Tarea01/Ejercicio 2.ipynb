# %%
#Ejercicio 2

print("Este programa repite el numero de veces deseado, la frase que introduzca")

a = input("Escriba la frase que desea repetir: ")
b = int(input("¿Cuantas veces desea repetir la frase?: "))
c = 0 

while c < b: 
  c = c+1
  print(a)
# Out:
# Este programa repite el numero de veces deseado, la frase que introduzca
