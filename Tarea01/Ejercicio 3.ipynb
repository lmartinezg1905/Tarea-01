# %%
#Ejercicio 3

print("Este preograma arrojara el sueldo dependiendo el tiempo trabajado")

def Sueldo(Horas, a=150):
     paga = Horas*a
     print("Recibira: ", paga)
     dia = paga*1
     semana = paga*5
     mes = paga*20
     print("Por un dia recibira: "+ str(dia))
     print("Por una semana recibira: "+ str(semana))
     print("Por un mes recibira: "+ str(mes))

Horas = int(input("Horas trabajadas: "))
Sueldo(Horas)
# Out:
# Este preograma arrojara el sueldo dependiendo el tiempo en horas trabajado
# HORAS trabajadas: 3
# Recibira:  450
# Por un dia recibira: 450
# Por una semana recibira: 2250
# Por un mes recibira: 9000
