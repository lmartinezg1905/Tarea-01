# %%
#Ejercicio 7

print("Este programa te da el costo de entrada al parque aplicando un descuento")

print("Seleccione una de las siguientes opciones para proporcionarle un precio")
print("1) Menor de 4 años, 2) Entre 4 y 16 años, 3) Adultos")
x = int(input("Indique su edad segun la opcion señalada: "))
print("Seleccione alguna de los siguientes descuentos disponibles si cuenta con alguna de las credenciales")
print("1) Estudiante con credencial, 2) Docente con credencial, 3) INAPAM, 4)Ninguna ")
y = int(input("Indique su descuento seleccionado: "))

if (x == 1 and y == 4):
  print("Usted ingresa gratis")

elif (x == 2 and y == 1):
  costo = 50 * 0.1
  total = 50 - costo
  print("El costo total con descuento sera de: ", total)

elif (x == 2 and y == 4):
  print("El costo total es de 50 pesos")

elif (x == 3 and y == 2):
  costo = 100 * 0.3
  total = 100 - costo
  print("El costo total con descuento sera de: ", total)

elif (x == 3 and y == 3):
  costo = 100 * 0.5
  total = 100 - costo
  print("El costo total con descuento sera de: ", total)

elif (x == 3 and y == 4):
  print("El costo total es de 100 pesos")
# Out:
# Este programa te da el costo de entrada al parque aplicando un descuento
# Seleccione una de las siguientes opciones para proporcionarle un precio
# 1) Menor de 4 años, 2) Entre 4 y 16 años, 3) Adultos
# Indique su edad segun la opcion señalada: 3
# Seleccione alguna de los siguientes descuentos disponibles si cuenta con alguna de las credenciales
# 1) Estudiante con credencial, 2) Docente con credencial, 3) INAPAM, 4)Ninguna
# Indique su descuento seleccionado: 4
# El costo total es de 100 pesos
